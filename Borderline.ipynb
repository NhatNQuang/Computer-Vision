# %% [markdown]
# DRAW BORDERLINE OF A IMAGE

# %%
from library import *

# %% [markdown]
# LÀM NỔI BẬT ĐƯỜNG BIÊN

# %%
img = load_image("C:\\Users\\nguye\\OneDrive\\Documents\\Nguyễn Quang Nhật\\Quang Nhat\\IMG_1043.JPG")

img1 = load_image("C:\\Users\\nguye\\OneDrive\\Documents\\Nguyễn Quang Nhật\\Quang Nhat\\IMG_5303.JPG")

# %%
# Because the image is 3D including the color, so changes to 2D or gray is needed.
img_gray = img.convert('L')

# %%
img_gray=img_gray.transpose(Image.Transpose.ROTATE_90)

# %%
# SHOW IMAGE ON Oxy
plt.imshow(img_gray)

# Tạo ra hình vẽ mới
plt.figure()

# Set it on Gray's color
plt.gray()

# Draw the borderline(contour)'s graph of image
plt.contour(img_gray, origin="image")

#Show image
plt.show()
